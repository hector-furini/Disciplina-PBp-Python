# %%
print(f"Testing docker as I wait...")
# Out:
# Testing docker as I wait...

# %%
from random import randint

# %%
lampada_ligada = randint(0, 1)
bocal_queimado = randint(0, 1)

print(lampada_ligada, bocal_queimado)

print(f"Lâmpada não funciona!!")
if lampada_ligada:
    if bocal_queimado:
        print(f"Substitua o bocal!")
    else:
        print(f"Compre uma lâmpada nova!")
else:
    print(f"Ligue a lâmpada!")
# Out:
# 1 0
# Lâmpada não funciona!!
# Compre uma lâmpada nova!
